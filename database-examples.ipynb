# %%
from IPython.display import Javascript, display
from ipywidgets import widgets

def run_all(ev):
    display(Javascript('IPython.notebook.execute_cells_below()'))

button = widgets.Button(description="Create next input")
button.on_click(run_all)
display(button)
# Out:
# Button(description='Create next input', style=ButtonStyle())

# %%
from ipywidgets import widgets, Layout, Box, GridspecLayout
##Basic mcq

def create_multipleChoice_widget(description, options, correct_answer, hint):
    if correct_answer not in options:
        options.append(correct_answer)
    
    correct_answer_index = options.index(correct_answer)
    
    radio_options = [(words, i) for i, words in enumerate(options)]
    alternativ = widgets.RadioButtons(
        options = radio_options,
        description = '',
        disabled = False,
        indent = False,
        align = 'center',
    )
    
    description_out = widgets.Output(layout=Layout(width='auto'))
    
    with description_out:
        print(description)
        
    feedback_out = widgets.Output()

    def check_selection(b):
        a = int(alternativ.value)
        if a==correct_answer_index:
            s = '\x1b[6;30;42m' + "correct" + '\x1b[0m' +"\n"
        else:
            s = '\x1b[5;30;41m' + "try again" + '\x1b[0m' +"\n"
        with feedback_out:
            feedback_out.clear_output()
            print(s)
        return
    
    check = widgets.Button(description="check")
    check.on_click(check_selection)
    
    hint_out = widgets.Output()
    
    def hint_selection(b):
        with hint_out:
            print(hint)
            
        with feedback_out:
            feedback_out.clear_output()
            print(hint)
    
    hintbutton = widgets.Button(description="hint")
    hintbutton.on_click(hint_selection)
    
    return widgets.VBox([description_out, 
                         alternativ, 
                         widgets.HBox([hintbutton, check]), feedback_out], 
                        layout=Layout(display='flex',
                                     flex_flow='column',
                                     align_items='stretch',
                                     width='auto')) 

##basic text input quiz

def create_textinputquiz_widget(description, text_description, correct_answer, a2, hint): ##grid for option table
    correct_answer = correct_answer ##float ##str   
    alternativ = widgets.Text(value = '',
                             placeholder = '',
                             description = '',
                             disabled = False, layout=(Layout(width = 'auto'))
                             )
##question description
    description_out = widgets.Output(layout=Layout(width='auto')) 
    with description_out:
        print(description)
##description before text widget    
    text_description_out = widgets.Output(layout=Layout(width='auto'))  
    with text_description_out:
        print (text_description)
##description after text widget e.g. units        
    a2_out = widgets.Output(layout=Layout(width='auto'))  
    with a2_out:
        print(a2)        
##
    feedback_out = widgets.Output()
    def check_selection(b):
        a = alternativ.value
        if a==correct_answer:
            s = '\x1b[6;30;42m' + "correct" + '\x1b[0m' +"\n" #green color
        else:
            s = '\x1b[5;30;41m' + "try again" + '\x1b[0m' +"\n" #red color
        with feedback_out:
            feedback_out.clear_output()
            print(s)
        return
    
    check = widgets.Button(description="check")
    check.on_click(check_selection)
##
    hint_out = widgets.Output()    
    def hint_selection(b):
        with hint_out:
            print(hint)            
        with feedback_out:
            feedback_out.clear_output()
            print(hint)
    
    hintbutton = widgets.Button(description="hint")
    hintbutton.on_click(hint_selection)         

    return widgets.VBox([description_out,
                         widgets.HBox([text_description_out, alternativ, a2_out]), 
                         widgets.HBox([hintbutton, check]), feedback_out], 
                        layout=Layout(display='flex',
                                     flex_flow='column',
                                     align_items='stretch',
                                     width='auto'))

# %%
a=create_multipleChoice_widget("asdfsa",["a","b","c"],"c","hint")

# %%
a
# Out:
# VBox(children=(Output(layout=Layout(width='auto')), RadioButtons(options=(('a', 0), ('b', 1), ('c', 2)), value…

# %%
b=create_textinputquiz_widget("asdfasdfs","ddddd","23","24","Hint")
b
# Out:
# VBox(children=(Output(layout=Layout(width='auto')), HBox(children=(Output(layout=Layout(width='auto')), Text(v…

# %%
import pandas as pn

# %%
# !git clone https://github.com/CSSEGISandData/COVID-19.git
# Out:
# fatal: destination path 'COVID-19' already exists and is not an empty directory.

# %%
# !ls COVID-19/csse_covid_19_data/csse_covid_19_daily_reports
# Out:
# 01-01-2021.csv	03-23-2020.csv	06-03-2020.csv	08-14-2020.csv	10-25-2020.csv
# 01-02-2021.csv	03-24-2020.csv	06-04-2020.csv	08-15-2020.csv	10-26-2020.csv
# 01-03-2021.csv	03-25-2020.csv	06-05-2020.csv	08-16-2020.csv	10-27-2020.csv
# 01-04-2021.csv	03-26-2020.csv	06-06-2020.csv	08-17-2020.csv	10-28-2020.csv
# 01-05-2021.csv	03-27-2020.csv	06-07-2020.csv	08-18-2020.csv	10-29-2020.csv
# 01-06-2021.csv	03-28-2020.csv	06-08-2020.csv	08-19-2020.csv	10-30-2020.csv
# 01-07-2021.csv	03-29-2020.csv	06-09-2020.csv	08-20-2020.csv	10-31-2020.csv
# 01-08-2021.csv	03-30-2020.csv	06-10-2020.csv	08-21-2020.csv	11-01-2020.csv
# 01-09-2021.csv	03-31-2020.csv	06-11-2020.csv	08-22-2020.csv	11-02-2020.csv
# 01-10-2021.csv	04-01-2020.csv	06-12-2020.csv	08-23-2020.csv	11-03-2020.csv
# 01-11-2021.csv	04-02-2020.csv	06-13-2020.csv	08-24-2020.csv	11-04-2020.csv
# 01-22-2020.csv	04-03-2020.csv	06-14-2020.csv	08-25-2020.csv	11-05-2020.csv
# 01-23-2020.csv	04-04-2020.csv	06-15-2020.csv	08-26-2020.csv	11-06-2020.csv
# 01-24-2020.csv	04-05-2020.csv	06-16-2020.csv	08-27-2020.csv	11-07-2020.csv
# 01-25-2020.csv	04-06-2020.csv	06-17-2020.csv	08-28-2020.csv	11-08-2020.csv
# 01-26-2020.csv	04-07-2020.csv	06-18-2020.csv	08-29-2020.csv	11-09-2020.csv
# 01-27-2020.csv	04-08-2020.csv	06-19-2020.csv	08-30-2020.csv	11-10-2020.csv
# 01-28-2020.csv	04-09-2020.csv	06-20-2020.csv	08-31-2020.csv	11-11-2020.csv
# 01-29-2020.csv	04-10-2020.csv	06-21-2020.csv	09-01-2020.csv	11-12-2020.csv
# 01-30-2020.csv	04-11-2020.csv	06-22-2020.csv	09-02-2020.csv	11-13-2020.csv
# 01-31-2020.csv	04-12-2020.csv	06-23-2020.csv	09-03-2020.csv	11-14-2020.csv
# 02-01-2020.csv	04-13-2020.csv	06-24-2020.csv	09-04-2020.csv	11-15-2020.csv
# 02-02-2020.csv	04-14-2020.csv	06-25-2020.csv	09-05-2020.csv	11-16-2020.csv
# 02-03-2020.csv	04-15-2020.csv	06-26-2020.csv	09-06-2020.csv	11-17-2020.csv
# 02-04-2020.csv	04-16-2020.csv	06-27-2020.csv	09-07-2020.csv	11-18-2020.csv
# 02-05-2020.csv	04-17-2020.csv	06-28-2020.csv	09-08-2020.csv	11-19-2020.csv
# 02-06-2020.csv	04-18-2020.csv	06-29-2020.csv	09-09-2020.csv	11-20-2020.csv
# 02-07-2020.csv	04-19-2020.csv	06-30-2020.csv	09-10-2020.csv	11-21-2020.csv
# 02-08-2020.csv	04-20-2020.csv	07-01-2020.csv	09-11-2020.csv	11-22-2020.csv
# 02-09-2020.csv	04-21-2020.csv	07-02-2020.csv	09-12-2020.csv	11-23-2020.csv
# 02-10-2020.csv	04-22-2020.csv	07-03-2020.csv	09-13-2020.csv	11-24-2020.csv
# 02-11-2020.csv	04-23-2020.csv	07-04-2020.csv	09-14-2020.csv	11-25-2020.csv
# 02-12-2020.csv	04-24-2020.csv	07-05-2020.csv	09-15-2020.csv	11-26-2020.csv
# 02-13-2020.csv	04-25-2020.csv	07-06-2020.csv	09-16-2020.csv	11-27-2020.csv
# 02-14-2020.csv	04-26-2020.csv	07-07-2020.csv	09-17-2020.csv	11-28-2020.csv
# 02-15-2020.csv	04-27-2020.csv	07-08-2020.csv	09-18-2020.csv	11-29-2020.csv
# 02-16-2020.csv	04-28-2020.csv	07-09-2020.csv	09-19-2020.csv	11-30-2020.csv
# 02-17-2020.csv	04-29-2020.csv	07-10-2020.csv	09-20-2020.csv	12-01-2020.csv
# 02-18-2020.csv	04-30-2020.csv	07-11-2020.csv	09-21-2020.csv	12-02-2020.csv
# 02-19-2020.csv	05-01-2020.csv	07-12-2020.csv	09-22-2020.csv	12-03-2020.csv
# 02-20-2020.csv	05-02-2020.csv	07-13-2020.csv	09-23-2020.csv	12-04-2020.csv
# 02-21-2020.csv	05-03-2020.csv	07-14-2020.csv	09-24-2020.csv	12-05-2020.csv
# 02-22-2020.csv	05-04-2020.csv	07-15-2020.csv	09-25-2020.csv	12-06-2020.csv
# 02-23-2020.csv	05-05-2020.csv	07-16-2020.csv	09-26-2020.csv	12-07-2020.csv
# 02-24-2020.csv	05-06-2020.csv	07-17-2020.csv	09-27-2020.csv	12-08-2020.csv
# 02-25-2020.csv	05-07-2020.csv	07-18-2020.csv	09-28-2020.csv	12-09-2020.csv
# 02-26-2020.csv	05-08-2020.csv	07-19-2020.csv	09-29-2020.csv	12-10-2020.csv
# 02-27-2020.csv	05-09-2020.csv	07-20-2020.csv	09-30-2020.csv	12-11-2020.csv
# 02-28-2020.csv	05-10-2020.csv	07-21-2020.csv	10-01-2020.csv	12-12-2020.csv
# 02-29-2020.csv	05-11-2020.csv	07-22-2020.csv	10-02-2020.csv	12-13-2020.csv
# 03-01-2020.csv	05-12-2020.csv	07-23-2020.csv	10-03-2020.csv	12-14-2020.csv
# 03-02-2020.csv	05-13-2020.csv	07-24-2020.csv	10-04-2020.csv	12-15-2020.csv
# 03-03-2020.csv	05-14-2020.csv	07-25-2020.csv	10-05-2020.csv	12-16-2020.csv
# 03-04-2020.csv	05-15-2020.csv	07-26-2020.csv	10-06-2020.csv	12-17-2020.csv
# 03-05-2020.csv	05-16-2020.csv	07-27-2020.csv	10-07-2020.csv	12-18-2020.csv
# 03-06-2020.csv	05-17-2020.csv	07-28-2020.csv	10-08-2020.csv	12-19-2020.csv
# 03-07-2020.csv	05-18-2020.csv	07-29-2020.csv	10-09-2020.csv	12-20-2020.csv
# 03-08-2020.csv	05-19-2020.csv	07-30-2020.csv	10-10-2020.csv	12-21-2020.csv
# 03-09-2020.csv	05-20-2020.csv	07-31-2020.csv	10-11-2020.csv	12-22-2020.csv
# 03-10-2020.csv	05-21-2020.csv	08-01-2020.csv	10-12-2020.csv	12-23-2020.csv
# 03-11-2020.csv	05-22-2020.csv	08-02-2020.csv	10-13-2020.csv	12-24-2020.csv
# 03-12-2020.csv	05-23-2020.csv	08-03-2020.csv	10-14-2020.csv	12-25-2020.csv
# 03-13-2020.csv	05-24-2020.csv	08-04-2020.csv	10-15-2020.csv	12-26-2020.csv
# 03-14-2020.csv	05-25-2020.csv	08-05-2020.csv	10-16-2020.csv	12-27-2020.csv
# 03-15-2020.csv	05-26-2020.csv	08-06-2020.csv	10-17-2020.csv	12-28-2020.csv
# 03-16-2020.csv	05-27-2020.csv	08-07-2020.csv	10-18-2020.csv	12-29-2020.csv
# 03-17-2020.csv	05-28-2020.csv	08-08-2020.csv	10-19-2020.csv	12-30-2020.csv
# 03-18-2020.csv	05-29-2020.csv	08-09-2020.csv	10-20-2020.csv	12-31-2020.csv
# 03-19-2020.csv	05-30-2020.csv	08-10-2020.csv	10-21-2020.csv	README.md
# 03-20-2020.csv	05-31-2020.csv	08-11-2020.csv	10-22-2020.csv
# 03-21-2020.csv	06-01-2020.csv	08-12-2020.csv	10-23-2020.csv
# 03-22-2020.csv	06-02-2020.csv	08-13-2020.csv	10-24-2020.csv

# %%
import pandas as pd
import numpy as np
import glob
import os

path = r'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))

df = pd.concat((pd.read_csv(f).assign(Date=lambda df: os.path.basename(f)[:-4]) for f in all_files))

# %%
df
# Out:
#      Province/State Country/Region          Last Update  Confirmed  Deaths  \
# 0             Hubei          China  2020-03-11T10:53:02    67773.0  3046.0
# 1               NaN          Italy  2020-03-11T21:33:02    12462.0   827.0
# 2               NaN           Iran  2020-03-11T18:52:03     9000.0   354.0
# 3               NaN   Korea, South  2020-03-11T21:13:18     7755.0    60.0
# 4            France         France  2020-03-11T22:53:03     2281.0    48.0
# ...             ...            ...                  ...        ...     ...
# 3971            NaN            NaN                  NaN     1410.0    35.0
# 3972            NaN            NaN                  NaN   119612.0  1097.0
# 3973            NaN            NaN                  NaN     2087.0   606.0
# 3974            NaN            NaN                  NaN    18575.0   373.0
# 3975            NaN            NaN                  NaN    12047.0   316.0
#
#       Recovered  Latitude  Longitude        Date  FIPS  ...  \
# 0       49134.0   30.9756   112.2707  03-11-2020   NaN  ...
# 1        1045.0   43.0000    12.0000  03-11-2020   NaN  ...
# 2        2959.0   32.0000    53.0000  03-11-2020   NaN  ...
# 3         288.0   36.0000   128.0000  03-11-2020   NaN  ...
# 4          12.0   46.2276     2.2137  03-11-2020   NaN  ...
# ...         ...       ...        ...         ...   ...  ...
# 3971     1266.0       NaN        NaN  12-18-2020   NaN  ...
# 3972    94556.0       NaN        NaN  12-18-2020   NaN  ...
# 3973     1384.0       NaN        NaN  12-18-2020   NaN  ...
# 3974    17729.0       NaN        NaN  12-18-2020   NaN  ...
# 3975     9894.0       NaN        NaN  12-18-2020   NaN  ...
#
#           Country_Region          Last_Update        Lat       Long_   Active  \
# 0                    NaN                  NaN        NaN         NaN      NaN
# 1                    NaN                  NaN        NaN         NaN      NaN
# 2                    NaN                  NaN        NaN         NaN      NaN
# 3                    NaN                  NaN        NaN         NaN      NaN
# 4                    NaN                  NaN        NaN         NaN      NaN
# ...                  ...                  ...        ...         ...      ...
# 3971             Vietnam  2020-12-19 05:27:52  14.058324  108.277199    109.0
# 3972  West Bank and Gaza  2020-12-19 05:27:52  31.952200   35.233200  23959.0
# 3973               Yemen  2020-12-19 05:27:52  15.552727   48.516388     97.0
# 3974              Zambia  2020-12-19 05:27:52 -13.133897   27.849332    473.0
# 3975            Zimbabwe  2020-12-19 05:27:52 -19.015438   29.154857   1837.0
#
#             Combined_Key  Incident_Rate Case_Fatality_Ratio  Incidence_Rate  \
# 0                    NaN            NaN                 NaN             NaN
# 1                    NaN            NaN                 NaN             NaN
# 2                    NaN            NaN                 NaN             NaN
# 3                    NaN            NaN                 NaN             NaN
# 4                    NaN            NaN                 NaN             NaN
# ...                  ...            ...                 ...             ...
# 3971             Vietnam       1.448552            2.482270             NaN
# 3972  West Bank and Gaza    2344.682339            0.917132             NaN
# 3973               Yemen       6.997258           29.036895             NaN
# 3974              Zambia     101.039189            2.008075             NaN
# 3975            Zimbabwe      81.054021            2.623060             NaN
#
#       Case-Fatality_Ratio
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 3971                  NaN
# 3972                  NaN
# 3973                  NaN
# 3974                  NaN
# 3975                  NaN
#
# [1114636 rows x 22 columns]

# %%
df.Date = pd.to_datetime(df.Date, format='%m-%d-%Y')

# %%
df[pd.notnull(df.Incidence_Rate)].Date.min()
# Out:
# Timestamp('2020-05-29 00:00:00')

# %%
df[pd.notnull(df.Incident_Rate)].Date.max()
# Out:
# Timestamp('2021-01-11 00:00:00')

# %%
df[pd.isnull(df.Confirmed)]
# Out:
#     Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 32         Qinghai  Mainland China    1/24/20 17:00        NaN     NaN
# 4            Gansu  Mainland China  1/22/2020 17:00        NaN     NaN
# 10    Heilongjiang  Mainland China  1/22/2020 17:00        NaN     NaN
# 12       Hong Kong       Hong Kong  1/22/2020 17:00        NaN     NaN
# 15  Inner Mongolia  Mainland China  1/22/2020 17:00        NaN     NaN
# 18           Jilin  Mainland China  1/22/2020 17:00        NaN     NaN
# 22         Qinghai  Mainland China  1/22/2020 17:00        NaN     NaN
# 23         Shaanxi  Mainland China  1/22/2020 17:00        NaN     NaN
# 30           Tibet  Mainland China  1/22/2020 17:00        NaN     NaN
# 32        Xinjiang  Mainland China  1/22/2020 17:00        NaN     NaN
# 15  Inner Mongolia  Mainland China    1/23/20 17:00        NaN     NaN
# 22         Qinghai  Mainland China    1/23/20 17:00        NaN     NaN
# 30           Tibet  Mainland China    1/23/20 17:00        NaN     NaN
# 39             NaN     Philippines    1/23/20 17:00        NaN     NaN
# 40             NaN        Malaysia    1/23/20 17:00        NaN     NaN
# 42             NaN       Australia    1/23/20 17:00        NaN     NaN
# 43             NaN          Mexico    1/23/20 17:00        NaN     NaN
# 44             NaN          Brazil    1/23/20 17:00        NaN     NaN
# 45             NaN        Colombia    1/23/20 17:00        NaN     NaN
#
#     Recovered  Latitude  Longitude       Date  FIPS  ... Country_Region  \
# 32        NaN       NaN        NaN 2020-01-24   NaN  ...            NaN
# 4         NaN       NaN        NaN 2020-01-22   NaN  ...            NaN
# 10        NaN       NaN        NaN 2020-01-22   NaN  ...            NaN
# 12        NaN       NaN        NaN 2020-01-22   NaN  ...            NaN
# 15        NaN       NaN        NaN 2020-01-22   NaN  ...            NaN
# 18        NaN       NaN        NaN 2020-01-22   NaN  ...            NaN
# 22        NaN       NaN        NaN 2020-01-22   NaN  ...            NaN
# 23        NaN       NaN        NaN 2020-01-22   NaN  ...            NaN
# 30        NaN       NaN        NaN 2020-01-22   NaN  ...            NaN
# 32        NaN       NaN        NaN 2020-01-22   NaN  ...            NaN
# 15        NaN       NaN        NaN 2020-01-23   NaN  ...            NaN
# 22        NaN       NaN        NaN 2020-01-23   NaN  ...            NaN
# 30        NaN       NaN        NaN 2020-01-23   NaN  ...            NaN
# 39        NaN       NaN        NaN 2020-01-23   NaN  ...            NaN
# 40        NaN       NaN        NaN 2020-01-23   NaN  ...            NaN
# 42        NaN       NaN        NaN 2020-01-23   NaN  ...            NaN
# 43        NaN       NaN        NaN 2020-01-23   NaN  ...            NaN
# 44        NaN       NaN        NaN 2020-01-23   NaN  ...            NaN
# 45        NaN       NaN        NaN 2020-01-23   NaN  ...            NaN
#
#    Last_Update Lat Long_  Active  Combined_Key  Incident_Rate  \
# 32         NaN NaN   NaN     NaN           NaN            NaN
# 4          NaN NaN   NaN     NaN           NaN            NaN
# 10         NaN NaN   NaN     NaN           NaN            NaN
# 12         NaN NaN   NaN     NaN           NaN            NaN
# 15         NaN NaN   NaN     NaN           NaN            NaN
# 18         NaN NaN   NaN     NaN           NaN            NaN
# 22         NaN NaN   NaN     NaN           NaN            NaN
# 23         NaN NaN   NaN     NaN           NaN            NaN
# 30         NaN NaN   NaN     NaN           NaN            NaN
# 32         NaN NaN   NaN     NaN           NaN            NaN
# 15         NaN NaN   NaN     NaN           NaN            NaN
# 22         NaN NaN   NaN     NaN           NaN            NaN
# 30         NaN NaN   NaN     NaN           NaN            NaN
# 39         NaN NaN   NaN     NaN           NaN            NaN
# 40         NaN NaN   NaN     NaN           NaN            NaN
# 42         NaN NaN   NaN     NaN           NaN            NaN
# 43         NaN NaN   NaN     NaN           NaN            NaN
# 44         NaN NaN   NaN     NaN           NaN            NaN
# 45         NaN NaN   NaN     NaN           NaN            NaN
#
#    Case_Fatality_Ratio  Incidence_Rate  Case-Fatality_Ratio
# 32                 NaN             NaN                  NaN
# 4                  NaN             NaN                  NaN
# 10                 NaN             NaN                  NaN
# 12                 NaN             NaN                  NaN
# 15                 NaN             NaN                  NaN
# 18                 NaN             NaN                  NaN
# 22                 NaN             NaN                  NaN
# 23                 NaN             NaN                  NaN
# 30                 NaN             NaN                  NaN
# 32                 NaN             NaN                  NaN
# 15                 NaN             NaN                  NaN
# 22                 NaN             NaN                  NaN
# 30                 NaN             NaN                  NaN
# 39                 NaN             NaN                  NaN
# 40                 NaN             NaN                  NaN
# 42                 NaN             NaN                  NaN
# 43                 NaN             NaN                  NaN
# 44                 NaN             NaN                  NaN
# 45                 NaN             NaN                  NaN
#
# [19 rows x 22 columns]

# %%
df.Date.max()
# Out:
# Timestamp('2021-01-11 00:00:00')

# %%
df2=df[pd.notnull(df.Incidence_Rate)][['Country_Region','Combined_Key','Date','Incidence_Rate','Confirmed']].assign(Popu=lambda df: (df.Confirmed/df.Incidence_Rate)*100000)

# %%
df2[df2.Combined_Key=='Catalonia, Spain']
# Out:
#      Country_Region      Combined_Key       Date  Incidence_Rate  Confirmed  \
# 3150          Spain  Catalonia, Spain 2020-06-15      791.614964    59897.0
# 3324          Spain  Catalonia, Spain 2020-08-01     1048.367454    79324.0
# 3307          Spain  Catalonia, Spain 2020-07-18      888.358065    67217.0
# 3165          Spain  Catalonia, Spain 2020-06-23      802.941307    60754.0
# 3085          Spain  Catalonia, Spain 2020-05-30      779.799618    59003.0
# ...             ...               ...        ...             ...        ...
# 587           Spain  Catalonia, Spain 2020-09-03     1500.958642   113569.0
# 587           Spain  Catalonia, Spain 2020-09-04     1519.699314   114987.0
# 587           Spain  Catalonia, Spain 2020-09-17     1685.656025   127544.0
# 3307          Spain  Catalonia, Spain 2020-07-19      888.358065    67217.0
# 589           Spain  Catalonia, Spain 2020-10-13     2137.982888   161769.0
#
#               Popu
# 3150  7.566431e+06
# 3324  7.566431e+06
# 3307  7.566431e+06
# 3165  7.566431e+06
# 3085  7.566431e+06
# ...            ...
# 587   7.566431e+06
# 587   7.566431e+06
# 587   7.566431e+06
# 3307  7.566431e+06
# 589   7.566431e+06
#
# [164 rows x 6 columns]

# %%
df['Country_Region']=np.where(pd.isnull(df.Country_Region),df['Country/Region'],df['Country_Region'])

# %%
df
# Out:
#      Province/State Country/Region          Last Update  Confirmed  Deaths  \
# 0             Hubei          China  2020-03-11T10:53:02    67773.0  3046.0
# 1               NaN          Italy  2020-03-11T21:33:02    12462.0   827.0
# 2               NaN           Iran  2020-03-11T18:52:03     9000.0   354.0
# 3               NaN   Korea, South  2020-03-11T21:13:18     7755.0    60.0
# 4            France         France  2020-03-11T22:53:03     2281.0    48.0
# ...             ...            ...                  ...        ...     ...
# 3971            NaN            NaN                  NaN     1410.0    35.0
# 3972            NaN            NaN                  NaN   119612.0  1097.0
# 3973            NaN            NaN                  NaN     2087.0   606.0
# 3974            NaN            NaN                  NaN    18575.0   373.0
# 3975            NaN            NaN                  NaN    12047.0   316.0
#
#       Recovered  Latitude  Longitude       Date  FIPS  ...  \
# 0       49134.0   30.9756   112.2707 2020-03-11   NaN  ...
# 1        1045.0   43.0000    12.0000 2020-03-11   NaN  ...
# 2        2959.0   32.0000    53.0000 2020-03-11   NaN  ...
# 3         288.0   36.0000   128.0000 2020-03-11   NaN  ...
# 4          12.0   46.2276     2.2137 2020-03-11   NaN  ...
# ...         ...       ...        ...        ...   ...  ...
# 3971     1266.0       NaN        NaN 2020-12-18   NaN  ...
# 3972    94556.0       NaN        NaN 2020-12-18   NaN  ...
# 3973     1384.0       NaN        NaN 2020-12-18   NaN  ...
# 3974    17729.0       NaN        NaN 2020-12-18   NaN  ...
# 3975     9894.0       NaN        NaN 2020-12-18   NaN  ...
#
#           Country_Region          Last_Update        Lat       Long_   Active  \
# 0                  China                  NaN        NaN         NaN      NaN
# 1                  Italy                  NaN        NaN         NaN      NaN
# 2                   Iran                  NaN        NaN         NaN      NaN
# 3           Korea, South                  NaN        NaN         NaN      NaN
# 4                 France                  NaN        NaN         NaN      NaN
# ...                  ...                  ...        ...         ...      ...
# 3971             Vietnam  2020-12-19 05:27:52  14.058324  108.277199    109.0
# 3972  West Bank and Gaza  2020-12-19 05:27:52  31.952200   35.233200  23959.0
# 3973               Yemen  2020-12-19 05:27:52  15.552727   48.516388     97.0
# 3974              Zambia  2020-12-19 05:27:52 -13.133897   27.849332    473.0
# 3975            Zimbabwe  2020-12-19 05:27:52 -19.015438   29.154857   1837.0
#
#             Combined_Key  Incident_Rate Case_Fatality_Ratio  Incidence_Rate  \
# 0                    NaN            NaN                 NaN             NaN
# 1                    NaN            NaN                 NaN             NaN
# 2                    NaN            NaN                 NaN             NaN
# 3                    NaN            NaN                 NaN             NaN
# 4                    NaN            NaN                 NaN             NaN
# ...                  ...            ...                 ...             ...
# 3971             Vietnam       1.448552            2.482270             NaN
# 3972  West Bank and Gaza    2344.682339            0.917132             NaN
# 3973               Yemen       6.997258           29.036895             NaN
# 3974              Zambia     101.039189            2.008075             NaN
# 3975            Zimbabwe      81.054021            2.623060             NaN
#
#       Case-Fatality_Ratio
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 3971                  NaN
# 3972                  NaN
# 3973                  NaN
# 3974                  NaN
# 3975                  NaN
#
# [1114636 rows x 22 columns]

# %%
covid=pn.read_csv("https://opendata.ecdc.europa.eu/covid19/casedistribution/csv")

# %%
covid
# Out:
#          dateRep year_week  cases_weekly  deaths_weekly  \
# 0     04/01/2021   2020-53           902             60
# 1     28/12/2020   2020-52          1994             88
# 2     21/12/2020   2020-51           740            111
# 3     14/12/2020   2020-50          1757             71
# 4     07/12/2020   2020-49          1672            137
# ...          ...       ...           ...            ...
# 9572  20/04/2020   2020-16            11              0
# 9573  13/04/2020   2020-15             5              2
# 9574  06/04/2020   2020-14             2              0
# 9575  30/03/2020   2020-13             5              1
# 9576  23/03/2020   2020-12             2              0
#
#      countriesAndTerritories geoId countryterritoryCode  popData2019  \
# 0                Afghanistan    AF                  AFG   38041757.0
# 1                Afghanistan    AF                  AFG   38041757.0
# 2                Afghanistan    AF                  AFG   38041757.0
# 3                Afghanistan    AF                  AFG   38041757.0
# 4                Afghanistan    AF                  AFG   38041757.0
# ...                      ...   ...                  ...          ...
# 9572                Zimbabwe    ZW                  ZWE   14645473.0
# 9573                Zimbabwe    ZW                  ZWE   14645473.0
# 9574                Zimbabwe    ZW                  ZWE   14645473.0
# 9575                Zimbabwe    ZW                  ZWE   14645473.0
# 9576                Zimbabwe    ZW                  ZWE   14645473.0
#
#      continentExp  notification_rate_per_100000_population_14-days
# 0            Asia                                             7.61
# 1            Asia                                             7.19
# 2            Asia                                             6.56
# 3            Asia                                             9.01
# 4            Asia                                             7.22
# ...           ...                                              ...
# 9572       Africa                                             0.11
# 9573       Africa                                             0.05
# 9574       Africa                                             0.05
# 9575       Africa                                             0.05
# 9576       Africa                                              NaN
#
# [9577 rows x 10 columns]
